# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('raw.csv')
data
# Out:
#               Date   Time             Datetime  50Hertz  Amprion   TenneT  \
# 0       01.01.2015  00:00  2015-01-01 00:00:00  2318.75  3781.25  3592.25
# 1       01.01.2015  00:15  2015-01-01 00:15:00  2310.00  3760.00  3555.75
# 2       01.01.2015  00:30  2015-01-01 00:30:00  2301.00  3824.50  3509.00
# 3       01.01.2015  00:45  2015-01-01 00:45:00  2281.75  3880.00  3453.25
# 4       01.01.2015  01:00  2015-01-01 01:00:00  2270.00  3829.00  3392.50
# ...            ...    ...                  ...      ...      ...      ...
# 280507  31.12.2022  22:45  2022-12-31 22:45:00  2361.75  3678.25  3187.25
# 280508  31.12.2022  23:00  2022-12-31 23:00:00  2292.50  3589.00  3194.75
# 280509  31.12.2022  23:15  2022-12-31 23:15:00  2280.75  3655.25  3156.50
# 280510  31.12.2022  23:30  2022-12-31 23:30:00  2274.75  3592.75  3140.00
# 280511  31.12.2022  23:45  2022-12-31 23:45:00  2237.50  3595.50  3085.25
#
#         TransnetBW     Total   Delta
# 0          1379.75  11210.00  138.00
# ...

# %%
n = 4 * 24 * 7 * 4

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(data['50Hertz'][:n], label='50Hertz')
ax.plot(data['Amprion'][:n], label='Amprion')
ax.plot(data['TenneT'][:n], label='TenneT')
ax.plot(data['TransnetBW'][:n], label='TransnetBW')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(data['Total'][:n], label='Total')
ax.legend()

# %%
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(data['Delta'][:n], label='Delta')
ax.legend()

# %%
n = 4 * 24 * 7
fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(data['50Hertz'][:n], label='50Hertz')
ax.plot(data['Amprion'][:n], label='Amprion')
ax.plot(data['TenneT'][:n], label='TenneT')
ax.plot(data['TransnetBW'][:n], label='TransnetBW')
ax.plot(data['Total'][:n], label='Total')
ax.plot(data['Delta'][:n], label='Delta')
ax.legend()
